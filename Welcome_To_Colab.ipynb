# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>Explore the Gemini API</h2>
#   <p>The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#   </p>
#   <strong>How to get started</strong>
#     <ol>
#       <li>Go to <a href="https://aistudio.google.com/">Google AI Studio</a> and log in with your Google account.</li>
#       <li><a href="https://aistudio.google.com/app/apikey">Create an API key</a>.</li>
#       <li>Use a quickstart for <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Prompting.ipynb">Python</a>, or call the REST API using <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb">curl</a>.</li>
#       </ol>
#   <strong>Explore use cases</strong>
#     <ul>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Market_a_Jet_Backpack.ipynb">Create a marketing campaign</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Audio.ipynb">Analyze audio recordings</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/System_instructions.ipynb">Use System instructions in chat</a></li>
#     </ul>
#   <p>To learn more, check out the <a href="https://github.com/google-gemini/cookbook">Gemini cookbook</a> or visit the <a href="https://ai.google.dev/docs/">Gemini API documentation</a>.
#   </p>
# </div>

# %% [markdown]
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"/content/Copy of DA_I_Autumn_23-24(1).csv")
print(df)
# Out:
#                               SAGE University, Bhopal  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                                   #
# 4                                                   1
# 5                                                   2
# 6                                                   3
# 7                                                   4
# 8                                                   5
# 9                                                   6
# 10                                                  7
# 11                                                  8
# 12                                                  9
# 13                                                 10
# 14                                                 11
# 15                                                 12
# 16                                                 13
# 17                                                 14
# 18                                                 15
# 19                                                 16
# 20                                                 17
# 21                                                 18
# 22                                                 19
# 23                                                 20
# 24                                                 21
# 25                                                 22
#
#                             SAGE University, Bhopal.1  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                        Faculty Name
# 4                        Faculty of Advance Computing
# 5                        Faculty of Advance Computing
# 6                        Faculty of Advance Computing
# 7                        Faculty of Advance Computing
# 8                        Faculty of Advance Computing
# 9                        Faculty of Advance Computing
# 10                       Faculty of Advance Computing
# 11                       Faculty of Advance Computing
# 12                       Faculty of Advance Computing
# 13                       Faculty of Advance Computing
# 14                       Faculty of Advance Computing
# 15                       Faculty of Advance Computing
# 16                       Faculty of Advance Computing
# 17                       Faculty of Advance Computing
# 18                       Faculty of Advance Computing
# 19                       Faculty of Advance Computing
# 20                       Faculty of Advance Computing
# 21                       Faculty of Advance Computing
# 22                       Faculty of Advance Computing
# 23                       Faculty of Advance Computing
# 24                       Faculty of Advance Computing
# 25                       Faculty of Advance Computing
#
#                             SAGE University, Bhopal.2  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                     Department Name
# 4                         SCHOOL OF ADVANCE COMPUTING
# 5                         SCHOOL OF ADVANCE COMPUTING
# 6                         SCHOOL OF ADVANCE COMPUTING
# 7                         SCHOOL OF ADVANCE COMPUTING
# 8                         SCHOOL OF ADVANCE COMPUTING
# 9                         SCHOOL OF ADVANCE COMPUTING
# 10                        SCHOOL OF ADVANCE COMPUTING
# 11                        SCHOOL OF ADVANCE COMPUTING
# 12                        SCHOOL OF ADVANCE COMPUTING
# 13                        SCHOOL OF ADVANCE COMPUTING
# 14                        SCHOOL OF ADVANCE COMPUTING
# 15                        SCHOOL OF ADVANCE COMPUTING
# 16                        SCHOOL OF ADVANCE COMPUTING
# 17                        SCHOOL OF ADVANCE COMPUTING
# 18                        SCHOOL OF ADVANCE COMPUTING
# 19                        SCHOOL OF ADVANCE COMPUTING
# 20                        SCHOOL OF ADVANCE COMPUTING
# 21                        SCHOOL OF ADVANCE COMPUTING
# 22                        SCHOOL OF ADVANCE COMPUTING
# 23                        SCHOOL OF ADVANCE COMPUTING
# 24                        SCHOOL OF ADVANCE COMPUTING
# 25                        SCHOOL OF ADVANCE COMPUTING
#
#                             SAGE University, Bhopal.3  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                  Program Group Name
# 4                                                  UG
# 5                                                  UG
# 6                                                  UG
# 7                                                  UG
# 8                                                  UG
# 9                                                  UG
# 10                                                 UG
# 11                                                 UG
# 12                                                 UG
# 13                                                 UG
# 14                                                 UG
# 15                                                 UG
# 16                                                 UG
# 17                                                 UG
# 18                                                 UG
# 19                                                 UG
# 20                                                 UG
# 21                                                 UG
# 22                                                 UG
# 23                                                 UG
# 24                                                 UG
# 25                                                 UG
#
#                             SAGE University, Bhopal.4  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                         Course Name
# 4               Bachelor of Technology - CSE (Honors)
# 5               Bachelor of Technology - CSE (Honors)
# 6               Bachelor of Technology - CSE (Honors)
# 7               Bachelor of Technology - CSE (Honors)
# 8               Bachelor of Technology - CSE (Honors)
# 9               Bachelor of Technology - CSE (Honors)
# 10              Bachelor of Technology - CSE (Honors)
# 11              Bachelor of Technology - CSE (Honors)
# 12              Bachelor of Technology - CSE (Honors)
# 13              Bachelor of Technology - CSE (Honors)
# 14              Bachelor of Technology - CSE (Honors)
# 15              Bachelor of Technology - CSE (Honors)
# 16              Bachelor of Technology - CSE (Honors)
# 17              Bachelor of Technology - CSE (Honors)
# 18              Bachelor of Technology - CSE (Honors)
# 19              Bachelor of Technology - CSE (Honors)
# 20              Bachelor of Technology - CSE (Honors)
# 21              Bachelor of Technology - CSE (Honors)
# 22              Bachelor of Technology - CSE (Honors)
# 23              Bachelor of Technology - CSE (Honors)
# 24              Bachelor of Technology - CSE (Honors)
# 25              Bachelor of Technology - CSE (Honors)
#
#                             SAGE University, Bhopal.5  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                         Branch Name
# 4                                      DATA ANALYTICS
# 5                                      DATA ANALYTICS
# 6                                      DATA ANALYTICS
# 7                                      DATA ANALYTICS
# 8                                      DATA ANALYTICS
# 9                                      DATA ANALYTICS
# 10                                     DATA ANALYTICS
# 11                                     DATA ANALYTICS
# 12                                     DATA ANALYTICS
# 13                                     DATA ANALYTICS
# 14                                     DATA ANALYTICS
# 15                                     DATA ANALYTICS
# 16                                     DATA ANALYTICS
# 17                                     DATA ANALYTICS
# 18                                     DATA ANALYTICS
# 19                                     DATA ANALYTICS
# 20                                     DATA ANALYTICS
# 21                                     DATA ANALYTICS
# 22                                     DATA ANALYTICS
# 23                                     DATA ANALYTICS
# 24                                     DATA ANALYTICS
# 25                                     DATA ANALYTICS
#
#                             SAGE University, Bhopal.6  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                          Class Name
# 4     B.Tech CSE (Hons) - Data Analytics - I Semester
# 5     B.Tech CSE (Hons) - Data Analytics - I Semester
# 6     B.Tech CSE (Hons) - Data Analytics - I Semester
# 7     B.Tech CSE (Hons) - Data Analytics - I Semester
# 8     B.Tech CSE (Hons) - Data Analytics - I Semester
# 9     B.Tech CSE (Hons) - Data Analytics - I Semester
# 10    B.Tech CSE (Hons) - Data Analytics - I Semester
# 11    B.Tech CSE (Hons) - Data Analytics - I Semester
# 12    B.Tech CSE (Hons) - Data Analytics - I Semester
# 13    B.Tech CSE (Hons) - Data Analytics - I Semester
# 14    B.Tech CSE (Hons) - Data Analytics - I Semester
# 15    B.Tech CSE (Hons) - Data Analytics - I Semester
# 16    B.Tech CSE (Hons) - Data Analytics - I Semester
# 17    B.Tech CSE (Hons) - Data Analytics - I Semester
# 18    B.Tech CSE (Hons) - Data Analytics - I Semester
# 19    B.Tech CSE (Hons) - Data Analytics - I Semester
# 20    B.Tech CSE (Hons) - Data Analytics - I Semester
# 21    B.Tech CSE (Hons) - Data Analytics - I Semester
# 22    B.Tech CSE (Hons) - Data Analytics - I Semester
# 23    B.Tech CSE (Hons) - Data Analytics - I Semester
# 24    B.Tech CSE (Hons) - Data Analytics - I Semester
# 25    B.Tech CSE (Hons) - Data Analytics - I Semester
#
#                             SAGE University, Bhopal.7  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                   Result Published?
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                Yes
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19                                                Yes
# 20                                                Yes
# 21                                                Yes
# 22                                                Yes
# 23                                                Yes
# 24                                                Yes
# 25                                                Yes
#
#                             SAGE University, Bhopal.8  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                    Enrolment Number
# 4                                      23BTA3BTS10015
# 5                                      23BTA3BTS10001
# 6                                      23BTA3BTS10020
# 7                                      23BTA3BTS11010
# 8                                      23BTA3BTS11018
# 9                                      23BTA3BTS11011
# 10                                     23BTA3BTS10016
# 11                                     23BTA3BTS10017
# 12                                     23BTA3BTS11004
# 13                                     23BTA3BTS10006
# 14                                     23BTA3BTS11014
# 15                                     23BTA3BTS10007
# 16                                     23BTA3BTS11021
# 17                                     23BTA3BTS11019
# 18                                     23BTA3BTS11013
# 19                                     23BTA3BTS11005
# 20                                     23BTA3BTS10009
# 21                                     23BTA3BTS11003
# 22                                     23BTA3BTS10002
# 23                                     23BTA3BTS10022
# 24                                     23BTA3BTS10023
# 25                                     23BTA3BTS10008
#
#                             SAGE University, Bhopal.9  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                      Scholar Number
# 4                                              232266
# 5                                              231955
# 6                                              232551
# 7                                              232267
# 8                                              231364
# 9                                              231951
# 10                                             232039
# 11                                             232589
# 12                                             232268
# 13                                             232559
# 14                                             231439
# 15                                             232541
# 16                                             230482
# 17                                             232552
# 18                                             232037
# 19                                             232649
# 20                                             232550
# 21                                             231961
# 22                                             232055
# 23                                             232036
# 24                                             232558
# 25                                             232540
#
#                            SAGE University, Bhopal.10  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                         Roll Number
# 4                                      23BTA3BTS10015
# 5                                      23BTA3BTS10001
# 6                                      23BTA3BTS10020
# 7                                      23BTA3BTS11010
# 8                                      23BTA3BTS11018
# 9                                      23BTA3BTS11011
# 10                                     23BTA3BTS10016
# 11                                     23BTA3BTS10017
# 12                                     23BTA3BTS11004
# 13                                     23BTA3BTS10006
# 14                                     23BTA3BTS11014
# 15                                     23BTA3BTS10007
# 16                                     23BTA3BTS11021
# 17                                     23BTA3BTS11019
# 18                                     23BTA3BTS11013
# 19                                     23BTA3BTS11005
# 20                                     23BTA3BTS10009
# 21                                     23BTA3BTS11003
# 22                                     23BTA3BTS10002
# 23                                     23BTA3BTS10022
# 24                                     23BTA3BTS10023
# 25                                     23BTA3BTS10008
#
#                            SAGE University, Bhopal.11  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                        Student Name
# 4                                      SHISHIR RANJAN
# 5                                 ADITYA SINGH BAGHEL
# 6                                      TEJASWI RANJAN
# 7                                       MANDEEP KUMAR
# 8                                        SURAJ  KUMAR
# 9                                   NISHANT NAVIN JHA
# 10                                     SHIVANSH SINGH
# 11                                  SHREE NATH MAHATO
# 12                                  ANKIT VISHWAKARMA
# 13                         DIVYANSH SINGH SURYAVANSHI
# 14                                        RUPAK KUMAR
# 15                                    JAYESH KUSHWAHA
# 16                             UTKARSH SADASHIV PATIL
# 17                                SURAJ NARAYAN SINGH
# 18                                        RAJ NANDANI
# 19                                    ARJUN CHAUDHARY
# 20                                KRISHNA MOHAN KUMAR
# 21                                  ANKIT KUMAR SAROJ
# 22                                       AKASH TIWARI
# 23                                           VAISHALI
# 24                                        ANKIT KUMAR
# 25                                    JAYSHREE TUMRAM
#
#                            SAGE University, Bhopal.12  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                              Gender
# 4                                                Male
# 5                                                Male
# 6                                                Male
# 7                                                Male
# 8                                                Male
# 9                                                Male
# 10                                               Male
# 11                                               Male
# 12                                               Male
# 13                                               Male
# 14                                               Male
# 15                                               Male
# 16                                               Male
# 17                                               Male
# 18                                             Female
# 19                                               Male
# 20                                               Male
# 21                                               Male
# 22                                               Male
# 23                                             Female
# 24                                               Male
# 25                                             Female
#
#                            SAGE University, Bhopal.13  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                            Category
# 4                                                 GEN
# 5                                                 GEN
# 6                                                 OBC
# 7                                                 OBC
# 8                                                 GEN
# 9                                                 GEN
# 10                                                GEN
# 11                                                GEN
# 12                                                OBC
# 13                                                GEN
# 14                                                GEN
# 15                                                OBC
# 16                                                GEN
# 17                                                GEN
# 18                                                OBC
# 19                                                GEN
# 20                                                GEN
# 21                                                 SC
# 22                                                GEN
# 23                                                 SC
# 24                                                GEN
# 25                                                GEN
#
#                            SAGE University, Bhopal.14  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                      Student Status
# 4                                             REGULAR
# 5                                             REGULAR
# 6                                             REGULAR
# 7                                             REGULAR
# 8                                             REGULAR
# 9                                             REGULAR
# 10                                            REGULAR
# 11                                            REGULAR
# 12                                            REGULAR
# 13                                            REGULAR
# 14                                            REGULAR
# 15                                            REGULAR
# 16                                            REGULAR
# 17                                            REGULAR
# 18                                            REGULAR
# 19                                            REGULAR
# 20                                            REGULAR
# 21                                            REGULAR
# 22                                            REGULAR
# 23                                            REGULAR
# 24                                            REGULAR
# 25                                            REGULAR
#
#                            SAGE University, Bhopal.15  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                              Result
# 4                                                PASS
# 5                                                PASS
# 6                                                PASS
# 7                                                PASS
# 8                                                PASS
# 9                                                PASS
# 10                                               PASS
# 11                                               PASS
# 12                                               PASS
# 13                                               PASS
# 14                                               PASS
# 15                                               PASS
# 16                                               PASS
# 17                                               PASS
# 18                                               PASS
# 19                                               PASS
# 20                                               PASS
# 21                                               PASS
# 22                                               PASS
# 23                                               PASS
# 24                                               PASS
# 25                                               ATKT
#
#                            SAGE University, Bhopal.16  \
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                                SGPA
# 4                                                9.38
# 5                                                9.38
# 6                                                8.92
# 7                                                8.71
# 8                                                8.71
# 9                                                8.63
# 10                                               8.58
# 11                                               8.50
# 12                                               8.46
# 13                                               8.38
# 14                                               8.17
# 15                                               8.08
# 16                                               8.08
# 17                                               8.00
# 18                                               7.96
# 19                                               7.92
# 20                                               7.67
# 21                                               7.46
# 22                                               7.21
# 23                                               6.92
# 24                                               6.46
# 25                                               7.46
#
#                            SAGE University, Bhopal.17
# 0   Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1   Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                 NaN
# 3                                                CGPA
# 4                                                9.38
# 5                                                9.38
# 6                                                8.92
# 7                                                8.71
# 8                                                8.71
# 9                                                8.63
# 10                                               8.58
# 11                                               8.50
# 12                                               8.46
# 13                                               8.38
# 14                                               8.17
# 15                                               8.08
# 16                                               8.08
# 17                                               8.00
# 18                                               7.96
# 19                                               7.92
# 20                                               7.67
# 21                                               7.46
# 22                                               7.21
# 23                                               6.92
# 24                                               6.46
# 25                                               7.46

# %%
df.head()
# Out:
#                              SAGE University, Bhopal  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                                  #
# 4                                                  1
#
#                            SAGE University, Bhopal.1  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                       Faculty Name
# 4                       Faculty of Advance Computing
#
#                            SAGE University, Bhopal.2  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                    Department Name
# 4                        SCHOOL OF ADVANCE COMPUTING
#
#                            SAGE University, Bhopal.3  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                 Program Group Name
# 4                                                 UG
#
#                            SAGE University, Bhopal.4  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                        Course Name
# 4              Bachelor of Technology - CSE (Honors)
#
#                            SAGE University, Bhopal.5  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                        Branch Name
# 4                                     DATA ANALYTICS
#
#                            SAGE University, Bhopal.6  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                         Class Name
# 4    B.Tech CSE (Hons) - Data Analytics - I Semester
#
#                            SAGE University, Bhopal.7  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                  Result Published?
# 4                                                Yes
#
#                            SAGE University, Bhopal.8  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                   Enrolment Number
# 4                                     23BTA3BTS10015
#
#                            SAGE University, Bhopal.9  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                     Scholar Number
# 4                                             232266
#
#                           SAGE University, Bhopal.10  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                        Roll Number
# 4                                     23BTA3BTS10015
#
#                           SAGE University, Bhopal.11  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                       Student Name
# 4                                     SHISHIR RANJAN
#
#                           SAGE University, Bhopal.12  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                             Gender
# 4                                               Male
#
#                           SAGE University, Bhopal.13  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                           Category
# 4                                                GEN
#
#                           SAGE University, Bhopal.14  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                     Student Status
# 4                                            REGULAR
#
#                           SAGE University, Bhopal.15  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                             Result
# 4                                               PASS
#
#                           SAGE University, Bhopal.16  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                               SGPA
# 4                                               9.38
#
#                           SAGE University, Bhopal.17
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                               CGPA
# 4                                               9.38

# %%
df.tail()
# Out:
#    SAGE University, Bhopal     SAGE University, Bhopal.1  \
# 21                      18  Faculty of Advance Computing
# 22                      19  Faculty of Advance Computing
# 23                      20  Faculty of Advance Computing
# 24                      21  Faculty of Advance Computing
# 25                      22  Faculty of Advance Computing
#
#       SAGE University, Bhopal.2 SAGE University, Bhopal.3  \
# 21  SCHOOL OF ADVANCE COMPUTING                        UG
# 22  SCHOOL OF ADVANCE COMPUTING                        UG
# 23  SCHOOL OF ADVANCE COMPUTING                        UG
# 24  SCHOOL OF ADVANCE COMPUTING                        UG
# 25  SCHOOL OF ADVANCE COMPUTING                        UG
#
#                 SAGE University, Bhopal.4 SAGE University, Bhopal.5  \
# 21  Bachelor of Technology - CSE (Honors)            DATA ANALYTICS
# 22  Bachelor of Technology - CSE (Honors)            DATA ANALYTICS
# 23  Bachelor of Technology - CSE (Honors)            DATA ANALYTICS
# 24  Bachelor of Technology - CSE (Honors)            DATA ANALYTICS
# 25  Bachelor of Technology - CSE (Honors)            DATA ANALYTICS
#
#                           SAGE University, Bhopal.6 SAGE University, Bhopal.7  \
# 21  B.Tech CSE (Hons) - Data Analytics - I Semester                       Yes
# 22  B.Tech CSE (Hons) - Data Analytics - I Semester                       Yes
# 23  B.Tech CSE (Hons) - Data Analytics - I Semester                       Yes
# 24  B.Tech CSE (Hons) - Data Analytics - I Semester                       Yes
# 25  B.Tech CSE (Hons) - Data Analytics - I Semester                       Yes
#
#    SAGE University, Bhopal.8 SAGE University, Bhopal.9  \
# 21            23BTA3BTS11003                    231961
# 22            23BTA3BTS10002                    232055
# 23            23BTA3BTS10022                    232036
# 24            23BTA3BTS10023                    232558
# 25            23BTA3BTS10008                    232540
#
#    SAGE University, Bhopal.10 SAGE University, Bhopal.11  \
# 21             23BTA3BTS11003          ANKIT KUMAR SAROJ
# 22             23BTA3BTS10002               AKASH TIWARI
# 23             23BTA3BTS10022                   VAISHALI
# 24             23BTA3BTS10023                ANKIT KUMAR
# 25             23BTA3BTS10008            JAYSHREE TUMRAM
#
#    SAGE University, Bhopal.12 SAGE University, Bhopal.13  \
# 21                       Male                         SC
# 22                       Male                        GEN
# 23                     Female                         SC
# 24                       Male                        GEN
# 25                     Female                        GEN
#
#    SAGE University, Bhopal.14 SAGE University, Bhopal.15  \
# 21                    REGULAR                       PASS
# 22                    REGULAR                       PASS
# 23                    REGULAR                       PASS
# 24                    REGULAR                       PASS
# 25                    REGULAR                       ATKT
#
#    SAGE University, Bhopal.16 SAGE University, Bhopal.17
# 21                       7.46                       7.46
# 22                       7.21                       7.21
# 23                       6.92                       6.92
# 24                       6.46                       6.46
# 25                       7.46                       7.46

# %%
df.dtypes
# Out:
# SAGE University, Bhopal       object
# SAGE University, Bhopal.1     object
# SAGE University, Bhopal.2     object
# SAGE University, Bhopal.3     object
# SAGE University, Bhopal.4     object
# SAGE University, Bhopal.5     object
# SAGE University, Bhopal.6     object
# SAGE University, Bhopal.7     object
# SAGE University, Bhopal.8     object
# SAGE University, Bhopal.9     object
# SAGE University, Bhopal.10    object
# SAGE University, Bhopal.11    object
# SAGE University, Bhopal.12    object
# SAGE University, Bhopal.13    object
# SAGE University, Bhopal.14    object
# SAGE University, Bhopal.15    object
# SAGE University, Bhopal.16    object
# SAGE University, Bhopal.17    object
# dtype: object

# %%
df.isnull().sum().sum()
# Out:
# 18

# %%
df.isnull().sum()
# Out:
# SAGE University, Bhopal       1
# SAGE University, Bhopal.1     1
# SAGE University, Bhopal.2     1
# SAGE University, Bhopal.3     1
# SAGE University, Bhopal.4     1
# SAGE University, Bhopal.5     1
# SAGE University, Bhopal.6     1
# SAGE University, Bhopal.7     1
# SAGE University, Bhopal.8     1
# SAGE University, Bhopal.9     1
# SAGE University, Bhopal.10    1
# SAGE University, Bhopal.11    1
# SAGE University, Bhopal.12    1
# SAGE University, Bhopal.13    1
# SAGE University, Bhopal.14    1
# SAGE University, Bhopal.15    1
# SAGE University, Bhopal.16    1
# SAGE University, Bhopal.17    1
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.drop(['SAGE University, Bhopal.1'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-ccd565fda64d> in <cell line: 1>()
# ----> 1 df.drop(['SAGE University, Bhopal.1'],axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['SAGE University, Bhopal.1'] not found in axis"

# %%
df.head()
# Out:
#                              SAGE University, Bhopal  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                                  #
# 4                                                  1
#
#                            SAGE University, Bhopal.2  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                    Department Name
# 4                        SCHOOL OF ADVANCE COMPUTING
#
#                            SAGE University, Bhopal.3  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                 Program Group Name
# 4                                                 UG
#
#                            SAGE University, Bhopal.4  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                        Course Name
# 4              Bachelor of Technology - CSE (Honors)
#
#                            SAGE University, Bhopal.5  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                        Branch Name
# 4                                     DATA ANALYTICS
#
#                            SAGE University, Bhopal.6  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                         Class Name
# 4    B.Tech CSE (Hons) - Data Analytics - I Semester
#
#                            SAGE University, Bhopal.7  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                  Result Published?
# 4                                                Yes
#
#                            SAGE University, Bhopal.8  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                   Enrolment Number
# 4                                     23BTA3BTS10015
#
#                            SAGE University, Bhopal.9  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                     Scholar Number
# 4                                             232266
#
#                           SAGE University, Bhopal.10  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                        Roll Number
# 4                                     23BTA3BTS10015
#
#                           SAGE University, Bhopal.11  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                       Student Name
# 4                                     SHISHIR RANJAN
#
#                           SAGE University, Bhopal.12  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                             Gender
# 4                                               Male
#
#                           SAGE University, Bhopal.13  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                           Category
# 4                                                GEN
#
#                           SAGE University, Bhopal.14  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                     Student Status
# 4                                            REGULAR
#
#                           SAGE University, Bhopal.15  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                             Result
# 4                                               PASS
#
#                           SAGE University, Bhopal.16  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                               SGPA
# 4                                               9.38
#
#                           SAGE University, Bhopal.17
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 2                                                NaN
# 3                                               CGPA
# 4                                               9.38

# %%
df=df.drop(labels=2,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-a5150b778a3d> in <cell line: 1>()
# ----> 1 df=df.drop(labels=2,axis=0)
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: '[2] not found in axis'

# %%
df.head()
# Out:
#                              SAGE University, Bhopal  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                                  #
# 4                                                  1
# 5                                                  2
#
#                            SAGE University, Bhopal.2  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                    Department Name
# 4                        SCHOOL OF ADVANCE COMPUTING
# 5                        SCHOOL OF ADVANCE COMPUTING
#
#                            SAGE University, Bhopal.3  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                 Program Group Name
# 4                                                 UG
# 5                                                 UG
#
#                            SAGE University, Bhopal.4  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                        Course Name
# 4              Bachelor of Technology - CSE (Honors)
# 5              Bachelor of Technology - CSE (Honors)
#
#                            SAGE University, Bhopal.5  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                        Branch Name
# 4                                     DATA ANALYTICS
# 5                                     DATA ANALYTICS
#
#                            SAGE University, Bhopal.6  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                         Class Name
# 4    B.Tech CSE (Hons) - Data Analytics - I Semester
# 5    B.Tech CSE (Hons) - Data Analytics - I Semester
#
#                            SAGE University, Bhopal.7  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                  Result Published?
# 4                                                Yes
# 5                                                Yes
#
#                            SAGE University, Bhopal.8  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                   Enrolment Number
# 4                                     23BTA3BTS10015
# 5                                     23BTA3BTS10001
#
#                            SAGE University, Bhopal.9  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                     Scholar Number
# 4                                             232266
# 5                                             231955
#
#                           SAGE University, Bhopal.10  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                        Roll Number
# 4                                     23BTA3BTS10015
# 5                                     23BTA3BTS10001
#
#                           SAGE University, Bhopal.11  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                       Student Name
# 4                                     SHISHIR RANJAN
# 5                                ADITYA SINGH BAGHEL
#
#                           SAGE University, Bhopal.12  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                             Gender
# 4                                               Male
# 5                                               Male
#
#                           SAGE University, Bhopal.13  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                           Category
# 4                                                GEN
# 5                                                GEN
#
#                           SAGE University, Bhopal.14  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                     Student Status
# 4                                            REGULAR
# 5                                            REGULAR
#
#                           SAGE University, Bhopal.15  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                             Result
# 4                                               PASS
# 5                                               PASS
#
#                           SAGE University, Bhopal.16  \
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                               SGPA
# 4                                               9.38
# 5                                               9.38
#
#                           SAGE University, Bhopal.17
# 0  Session : 2023-2024 | Exam Session : AUTUMN SE...
# 1  Detailed Result - Class Wise - B.Tech CSE (Hon...
# 3                                               CGPA
# 4                                               9.38
# 5                                               9.38

# %%
df.shape
# Out:
# (25, 17)

# %%
df.count()
# Out:
# SAGE University, Bhopal       25
# SAGE University, Bhopal.2     25
# SAGE University, Bhopal.3     25
# SAGE University, Bhopal.4     25
# SAGE University, Bhopal.5     25
# SAGE University, Bhopal.6     25
# SAGE University, Bhopal.7     25
# SAGE University, Bhopal.8     25
# SAGE University, Bhopal.9     25
# SAGE University, Bhopal.10    25
# SAGE University, Bhopal.11    25
# SAGE University, Bhopal.12    25
# SAGE University, Bhopal.13    25
# SAGE University, Bhopal.14    25
# SAGE University, Bhopal.15    25
# SAGE University, Bhopal.16    25
# SAGE University, Bhopal.17    25
# dtype: int64

# %%
sns.boxplot(x=df['SAGE University, Bhopal.12'])
# Out:
# <Axes: xlabel='SAGE University, Bhopal.12'>

# %%
sns.boxplot(df['SAGE University, Bhopal.16'])
# Out:
# <Axes: ylabel='SAGE University, Bhopal.16'>

# %%
sns.displot(df['SAGE University, Bhopal.16'])

# %%
y=df['SAGE University, Bhopal.9']
x=df['SAGE University, Bhopal.16']
plt.bar(x,y)
plt.show()

# %%
y=df['SAGE University, Bhopal.9']
x=df['SAGE University, Bhopal.16']
plt.plot(x,y)
plt.show()
